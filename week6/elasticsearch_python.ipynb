# %% [markdown]
# ## Querying Elastic Search engine with elasticsearch-dsl python package
#
# In this week we will try to send queirs to elastic search engine with Python. We will use the [elasticsearch-dsl](https://elasticsearch-dsl.readthedocs.io/en/latest/index.html) package which is a high-level library whose aim is to help with writing and running queries against Elasticsearch. It is built on top of the official low-level client (elasticsearch-py).
#
# It provides a more convenient and idiomatic way to write and manipulate queries. It stays close to the Elasticsearch JSON DSL, mirroring its terminology and structure.

# %%
import pandas as pd
import requests

# %%
# !pip install elasticsearch-dsl
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting elasticsearch-dsl
#   Downloading elasticsearch_dsl-7.1.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 284 kB/s eta 0:00:01
# Collecting elasticsearch<8.0.0,>=7.0.0
#   Downloading elasticsearch-7.6.0-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 414 kB/s eta 0:00:011
# Requirement already satisfied: python-dateutil in /Applications/anaconda/lib/python3.6/site-packages (from elasticsearch-dsl) (2.8.0)
# Requirement already satisfied: six in /Applications/anaconda/lib/python3.6/site-packages (from elasticsearch-dsl) (1.14.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Applications/anaconda/lib/python3.6/site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (1.25.3)
# Installing collected packages: elasticsearch, elasticsearch-dsl
# Successfully installed elasticsearch-7.6.0 elasticsearch-dsl-7.1.0

# %%
import elasticsearch_dsl
from elasticsearch_dsl import connections

# %%
connections.create_connection(alias='elastic', hosts=['https://1b12ab3f80124603bff9a8d923548521.us-east-1.aws.found.io:9243'],
                             timeout=60, http_auth=('elastic','zMJcA6De12xdU8OiVmOtDCu4'))
# Out:
# <Elasticsearch([{'host': '1b12ab3f80124603bff9a8d923548521.us-east-1.aws.found.io', 'port': 9243, 'use_ssl': True}])>

# %%
from elasticsearch import Elasticsearch
client = Elasticsearch('https://elastic:zMJcA6De12xdU8OiVmOtDCu4@1b12ab3f80124603bff9a8d923548521.us-east-1.aws.found.io:9243/kibana_sample_data_ecommerce/')

# %%
from elasticsearch_dsl import Q, Search

q = Q("match", customer_id="41") 

s = Search().using(client).query(q)
response = s.execute()

# %%
response
# Out:
# <Response: [<Hit(kibana_sample_data_ecommerce/cM-6MHEB7buSyQM2s8sN): {'category': ["Men's Clothing"], 'currency': 'EUR', 'custome...}>, <Hit(kibana_sample_data_ecommerce/zc-6MHEB7buSyQM2s8sN): {'category': ["Men's Clothing"], 'currency': 'EUR', 'custome...}>, <Hit(kibana_sample_data_ecommerce/xs-6MHEB7buSyQM2s8wP): {'category': ["Men's Shoes", "Men's Accessories"], 'currency...}>, <Hit(kibana_sample_data_ecommerce/1c-6MHEB7buSyQM2s8wP): {'category': ["Men's Accessories", "Men's Shoes"], 'currency...}>, <Hit(kibana_sample_data_ecommerce/_M-6MHEB7buSyQM2s8wP): {'category': ["Men's Accessories", "Men's Clothing"], 'curre...}>, <Hit(kibana_sample_data_ecommerce/Hs-6MHEB7buSyQM2s80P): {'category': ["Men's Clothing"], 'currency': 'EUR', 'custome...}>, <Hit(kibana_sample_data_ecommerce/Us-6MHEB7buSyQM2ytOa): {'category': ["Men's Accessories", "Men's Clothing"], 'curre...}>, <Hit(kibana_sample_data_ecommerce/Y8-6MHEB7buSyQM2ytOa): {'category': ["Men's Clothing"], 'currency': 'EUR', 'custome...}>, <Hit(kibana_sample_data_ecommerce/jc-6MHEB7buSyQM2ytOa): {'category': ["Men's Shoes", "Men's Clothing"], 'currency': ...}>, <Hit(kibana_sample_data_ecommerce/n8-6MHEB7buSyQM2ytOa): {'category': ["Men's Shoes", "Men's Clothing"], 'currency': ...}>]>

# %%
print(s.to_dict())
# Out:
# {'query': {'match': {'customer_id': '41'}}}

# %%
df = []
for h in response.hits.hits:
    df.append(h["_source"].to_dict())

# %%
pd.DataFrame(df)
# Out:
#                               category currency customer_first_name  \
# 0                     [Men's Clothing]      EUR                 Jim
# 1                     [Men's Clothing]      EUR                 Jim
# 2     [Men's Shoes, Men's Accessories]      EUR                 Jim
# 3     [Men's Accessories, Men's Shoes]      EUR                 Jim
# 4  [Men's Accessories, Men's Clothing]      EUR                 Jim
# 5                     [Men's Clothing]      EUR                 Jim
# 6  [Men's Accessories, Men's Clothing]      EUR                 Jim
# 7                     [Men's Clothing]      EUR                 Jim
# 8        [Men's Shoes, Men's Clothing]      EUR                 Jim
# 9        [Men's Shoes, Men's Clothing]      EUR                 Jim
#
#   customer_full_name customer_gender  customer_id customer_last_name  \
# 0          Jim Dixon            MALE           41              Dixon
# 1          Jim Lewis            MALE           41              Lewis
# 2           Jim Rowe            MALE           41               Rowe
# 3         Jim Jensen            MALE           41             Jensen
# 4        Jim Sanders            MALE           41            Sanders
# 5           Jim Love            MALE           41               Love
# 6         Jim Ramsey            MALE           41             Ramsey
# 7        Jim Stewart            MALE           41            Stewart
# 8         Jim Foster            MALE           41             Foster
# 9      Jim Henderson            MALE           41          Henderson
#
#   customer_phone day_of_week  day_of_week_i  ...                 order_date  \
# 0                   Saturday              5  ...  2020-03-21T10:53:46+00:00
# 1                   Thursday              3  ...  2020-04-09T06:21:36+00:00
# 2                     Friday              4  ...  2020-03-27T12:57:36+00:00
# 3                     Monday              0  ...  2020-03-23T21:02:53+00:00
# 4                  Wednesday              2  ...  2020-03-25T14:47:02+00:00
# 5                     Monday              0  ...  2020-04-13T10:20:38+00:00
# 6                     Sunday              6  ...  2020-04-12T22:40:48+00:00
# 7                    Tuesday              1  ...  2020-03-31T16:53:46+00:00
# 8                     Monday              0  ...  2020-04-13T01:20:38+00:00
# 9                  Wednesday              2  ...  2020-04-08T05:38:24+00:00
#
#   order_id                                           products  \
# 0   553689  [{'base_price': 32.99, 'discount_percentage': ...
# 1   579005  [{'base_price': 10.99, 'discount_percentage': ...
# 2   561969  [{'base_price': 41.99, 'discount_percentage': ...
# 3   556939  [{'base_price': 11.99, 'discount_percentage': ...
# 4   559344  [{'base_price': 11.99, 'discount_percentage': ...
# 5   584718  [{'base_price': 49.99, 'discount_percentage': ...
# 6   584070  [{'base_price': 84.99, 'discount_percentage': ...
# 7   567592  [{'base_price': 28.99, 'discount_percentage': ...
# 8   584234  [{'base_price': 74.99, 'discount_percentage': ...
# 9   577635  [{'base_price': 64.99, 'discount_percentage': ...
#
#                             sku  taxful_total_price taxless_total_price  \
# 0  [ZO0416304163, ZO0530405304]               61.98               61.98
# 1  [ZO0629306293, ZO0578405784]               37.98               37.98
# 2  [ZO0521205212, ZO0316003160]               74.98               74.98
# 3  [ZO0463404634, ZO0404804048]               76.98               76.98
# 4  [ZO0596105961, ZO0588805888]               32.98               32.98
# 5  [ZO0428604286, ZO0579905799]               72.98               72.98
# 6  [ZO0467304673, ZO0530605306]              113.98              113.98
# 7  [ZO0535405354, ZO0291302913]              228.98              228.98
# 8  [ZO0400704007, ZO0565605656]               87.98               87.98
# 9  [ZO0687406874, ZO0566105661]               79.98               79.98
#
#   total_quantity  total_unique_products   type  user
# 0              2                      2  order   jim
# 1              2                      2  order   jim
# 2              2                      2  order   jim
# 3              2                      2  order   jim
# 4              2                      2  order   jim
# 5              2                      2  order   jim
# 6              2                      2  order   jim
# 7              2                      2  order   jim
# 8              2                      2  order   jim
# 9              2                      2  order   jim
#
# [10 rows x 23 columns]

# %% [markdown]
# #### combining queries

# %%
q = Q("match", customer_gender="FEMALE") | Q("match", category="shoes")

s = Search().using(client).query(q)
response = s.execute()

# %%
s.to_dict()
# Out:
# {'query': {'bool': {'should': [{'match': {'customer_gender': 'FEMALE'}},
#     {'match': {'category': 'shoes'}}]}}}

# %%
df = []
for h in response.hits.hits:
    df.append(h["_source"].to_dict())
    
pd.DataFrame(df)
# Out:
#           category currency customer_first_name  customer_full_name  \
# 0  [Women's Shoes]      EUR                Gwen         Gwen Stokes
# 1  [Women's Shoes]      EUR                Mary           Mary Wood
# 2  [Women's Shoes]      EUR           Rabbia Al      Rabbia Al Moss
# 3  [Women's Shoes]      EUR             Abigail      Abigail Potter
# 4  [Women's Shoes]      EUR            Brigitte    Brigitte Goodman
# 5  [Women's Shoes]      EUR              Elyssa        Elyssa Reese
# 6  [Women's Shoes]      EUR       Wilhemina St.  Wilhemina St. Ball
# 7  [Women's Shoes]      EUR               Sonya         Sonya Lloyd
# 8  [Women's Shoes]      EUR             Yasmine    Yasmine Mckinney
# 9  [Women's Shoes]      EUR            Brigitte     Brigitte Barber
#
#   customer_gender  customer_id customer_last_name customer_phone day_of_week  \
# 0          FEMALE           26             Stokes                    Tuesday
# 1          FEMALE           20               Wood                   Saturday
# 2          FEMALE            5               Moss                    Tuesday
# 3          FEMALE           46             Potter                     Sunday
# 4          FEMALE           12            Goodman                     Friday
# 5          FEMALE           27              Reese                     Sunday
# 6          FEMALE           17               Ball                   Thursday
# 7          FEMALE           28              Lloyd                   Saturday
# 8          FEMALE           43           Mckinney                   Saturday
# 9          FEMALE           12             Barber                   Saturday
#
#    day_of_week_i  ...                 order_date order_id  \
# 0              1  ...  2020-03-24T13:26:24+00:00   557899
# 1              5  ...  2020-04-04T22:35:02+00:00   573302
# 2              1  ...  2020-03-24T05:45:36+00:00   557447
# 3              6  ...  2020-04-12T23:19:41+00:00   584113
# 4              4  ...  2020-04-03T07:52:19+00:00   571128
# 5              6  ...  2020-04-05T13:07:41+00:00   574115
# 6              3  ...  2020-03-26T13:45:07+00:00   560628
# 7              5  ...  2020-04-18T07:26:24+00:00   591195
# 8              5  ...  2020-03-21T00:21:36+00:00   553099
# 9              5  ...  2020-04-11T09:15:50+00:00   581886
#
#                                             products  \
# 0  [{'base_price': 64.99, 'discount_percentage': ...
# 1  [{'base_price': 28.99, 'discount_percentage': ...
# 2  [{'base_price': 84.99, 'discount_percentage': ...
# 3  [{'base_price': 64.99, 'discount_percentage': ...
# 4  [{'base_price': 28.99, 'discount_percentage': ...
# 5  [{'base_price': 11.99, 'discount_percentage': ...
# 6  [{'base_price': 28.99, 'discount_percentage': ...
# 7  [{'base_price': 29.99, 'discount_percentage': ...
# 8  [{'base_price': 24.99, 'discount_percentage': ...
# 9  [{'base_price': 69.99, 'discount_percentage': ...
#
#                             sku  taxful_total_price taxless_total_price  \
# 0  [ZO0375403754, ZO0673306733]              154.98              154.98
# 1  [ZO0008100081, ZO0017000170]               57.98               57.98
# 2  [ZO0247302473, ZO0669706697]              144.98              144.98
# 3  [ZO0679806798, ZO0244902449]              139.98              139.98
# 4  [ZO0140701407, ZO0003800038]               53.98               53.98
# 5  [ZO0002000020, ZO0137701377]               36.98               36.98
# 6  [ZO0143801438, ZO0674006740]              103.98              103.98
# 7  [ZO0140301403, ZO0383103831]               89.98               89.98
# 8  [ZO0010600106, ZO0018900189]               66.98               66.98
# 9  [ZO0665706657, ZO0027400274]              102.98              102.98
#
#   total_quantity  total_unique_products   type       user
# 0              2                      2  order       gwen
# 1              2                      2  order       mary
# 2              2                      2  order     rabbia
# 3              2                      2  order    abigail
# 4              2                      2  order   brigitte
# 5              2                      2  order     elyssa
# 6              2                      2  order  wilhemina
# 7              2                      2  order      sonya
# 8              2                      2  order    yasmine
# 9              2                      2  order   brigitte
#
# [10 rows x 23 columns]

# %% [markdown]
# #### filtering
# As opposed to `match` filtering aims to answer the question "how does the record match the query clause?", so the answer is a simple yes or no and there is no score involved (https://www.elastic.co/guide/en/elasticsearch/reference/2.0/query-filter-context.html).

# %%
s = Search().using(client).filter('terms', day_of_week=['Tuesday', 'Thursday'])
response = s.execute()

# %%
s.to_dict()
# Out:
# {'query': {'bool': {'filter': [{'terms': {'day_of_week': ['Tuesday',
#        'Thursday']}}]}}}

# %%
df = []
for h in response.hits.hits:
    df.append(h["_source"].to_dict())
    
pd.DataFrame(df)
# Out:
#                                category currency customer_first_name  \
# 0                      [Men's Clothing]      EUR            Ahmed Al
# 1                       [Women's Shoes]      EUR               rania
# 2                       [Women's Shoes]      EUR              Elyssa
# 3  [Women's Shoes, Women's Accessories]      EUR                Mary
# 4  [Women's Shoes, Women's Accessories]      EUR            Brigitte
# 5                    [Women's Clothing]      EUR              Selena
# 6                      [Men's Clothing]      EUR          Fitzgerald
# 7         [Men's Clothing, Men's Shoes]      EUR               Recip
# 8     [Women's Clothing, Women's Shoes]      EUR       Wilhemina St.
# 9     [Women's Shoes, Women's Clothing]      EUR               rania
#
#    customer_full_name customer_gender  customer_id customer_last_name  \
# 0     Ahmed Al Morris            MALE            4             Morris
# 1       rania Gilbert          FEMALE           24            Gilbert
# 2    Elyssa Mccormick          FEMALE           27          Mccormick
# 3          Mary Adams          FEMALE           20              Adams
# 4    Brigitte Schultz          FEMALE           12            Schultz
# 5      Selena Goodman          FEMALE           42            Goodman
# 6  Fitzgerald Schultz            MALE           11            Schultz
# 7       Recip Perkins            MALE           10            Perkins
# 8  Wilhemina St. Tran          FEMALE           17               Tran
# 9       rania Clayton          FEMALE           24            Clayton
#
#   customer_phone day_of_week  day_of_week_i  ...                 order_date  \
# 0                    Tuesday              1  ...  2020-04-14T19:53:46+00:00
# 1                   Thursday              3  ...  2020-04-02T12:28:48+00:00
# 2                    Tuesday              1  ...  2020-04-07T03:31:41+00:00
# 3                    Tuesday              1  ...  2020-04-07T07:56:38+00:00
# 4                    Tuesday              1  ...  2020-04-07T08:38:24+00:00
# 5                    Tuesday              1  ...  2020-04-07T09:43:12+00:00
# 6                    Tuesday              1  ...  2020-04-14T12:10:05+00:00
# 7                    Tuesday              1  ...  2020-04-14T12:46:05+00:00
# 8                    Tuesday              1  ...  2020-04-14T13:40:48+00:00
# 9                    Tuesday              1  ...  2020-04-14T15:07:12+00:00
#
#   order_id                                           products  \
# 0   586554  [{'base_price': 11.99, 'discount_percentage': ...
# 1   570056  [{'base_price': 24.99, 'discount_percentage': ...
# 2   576208  [{'base_price': 64.99, 'discount_percentage': ...
# 3   576454  [{'base_price': 64.99, 'discount_percentage': ...
# 4   576501  [{'base_price': 59.99, 'discount_percentage': ...
# 5   576557  [{'base_price': 10.99, 'discount_percentage': ...
# 6   586119  [{'base_price': 24.99, 'discount_percentage': ...
# 7   586157  [{'base_price': 10.99, 'discount_percentage': ...
# 8   586213  [{'base_price': 32.99, 'discount_percentage': ...
# 9   586303  [{'base_price': 28.99, 'discount_percentage': ...
#
#                             sku  taxful_total_price taxless_total_price  \
# 0  [ZO0441604416, ZO0113501135]               44.98               44.98
# 1  [ZO0131801318, ZO0215802158]               49.98               49.98
# 2  [ZO0666606666, ZO0139201392]               97.98               97.98
# 3  [ZO0245302453, ZO0357203572]              129.98              129.98
# 4  [ZO0323203232, ZO0194201942]               73.98               73.98
# 5  [ZO0641506415, ZO0171301713]               22.98               22.98
# 6  [ZO0630306303, ZO0532605326]               41.98               41.98
# 7  [ZO0130401304, ZO0509705097]               27.98               27.98
# 8  [ZO0225502255, ZO0031400314]               74.98               74.98
# 9  [ZO0003300033, ZO0712307123]               47.98               47.98
#
#   total_quantity  total_unique_products   type       user
# 0              2                      2  order      ahmed
# 1              2                      2  order       rani
# 2              2                      2  order     elyssa
# 3              2                      2  order       mary
# 4              2                      2  order   brigitte
# 5              2                      2  order     selena
# 6              2                      2  order      fuzzy
# 7              2                      2  order      recip
# 8              2                      2  order  wilhemina
# 9              2                      2  order       rani
#
# [10 rows x 23 columns]

# %% [markdown]
# #### Aggregations

# %%
from elasticsearch_dsl import A

a = A('terms', field='customer_gender')

# %%
s = Search().using(client)
s.aggs.bucket('gender', 'terms', field='customer_gender')\
    .metric('num_customers', 'value_count', field='customer_id')
# Out:
# Terms(aggs={'num_customers': ValueCount(field='customer_id')}, field='customer_gender')

# %%
s.to_dict()
# Out:
# {'aggs': {'gender': {'terms': {'field': 'customer_gender'},
#    'aggs': {'num_customers': {'value_count': {'field': 'customer_id'}}}}}}

# %%
response = s.execute()

# %%
response.aggregations.to_dict()
# Out:
# {'gender': {'doc_count_error_upper_bound': 0,
#   'sum_other_doc_count': 0,
#   'buckets': [{'key': 'FEMALE',
#     'doc_count': 2433,
#     'num_customers': {'value': 2433}},
#    {'key': 'MALE', 'doc_count': 2242, 'num_customers': {'value': 2242}}]}}

# %%
df = []
for r in response.aggregations.gender.buckets:
    df.append(r.to_dict())
pd.DataFrame(df)
# Out:
#    doc_count     key    num_customers
# 0       2433  FEMALE  {'value': 2433}
# 1       2242    MALE  {'value': 2242}
